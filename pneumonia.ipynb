# %%
import os
import numpy as np
import pandas as pd 
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = 'chest_xray/chest_xray'

fig, ax = plt.subplots(2, 3, figsize=(15, 7))
ax = ax.ravel()
plt.tight_layout()

for i, _set in enumerate(['train', 'val', 'test']):
    set_path = data + _set
    ax[i].imshow(plt.imread(set_path+'/NORMAL/'+os.listdir(set_path+'/NORMAL')[0]), cmap='gray')
    ax[i].set_title('Set: {}, Condition: Normal'.format(_set))
    ax[i+3].imshow(plt.imread(set_path+'/PNEUMONIA/'+os.listdir(set_path+'/PNEUMONIA')[0]), cmap='gray')
    ax[i+3].set_title('Set: {}, Condition: Pneumonia'.format(_set))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4269390f7f60> in <module>
#       7 for i, _set in enumerate(['train', 'val', 'test']):
#       8     set_path = data + _set
# ----> 9     ax[i].imshow(plt.imread(set_path+'/NORMAL/'+os.listdir(set_path+'/NORMAL')[0]), cmap='gray')
#      10     ax[i].set_title('Set: {}, Condition: Normal'.format(_set))
#      11     ax[i+3].imshow(plt.imread(set_path+'/PNEUMONIA/'+os.listdir(set_path+'/PNEUMONIA')[0]), cmap='gray')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'chest_xray/chest_xraytrain/NORMAL'
